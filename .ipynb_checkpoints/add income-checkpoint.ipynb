# %%
import pandas as pd
import numpy as np
import random

# %%
names = pd.read_csv('transaction.csv')['name']
names = pd.DataFrame(list(set(names)), columns=['name'])
transaction = pd.read_csv('transaction.csv')

# %%
salaryList= []
for i in range(names.shape[0]):
#     if i %1000 == 0: print('zx')
    name = names.iloc[i]['name']
    total = sum(transaction.loc[transaction['name'] == name, 'amount'])
    percentage = random.randrange(-10,1000)
    
    total += total * (percentage/100.0)
    
#     print(total, percentage)
    salaryList.append(total)
    
    
names['salary'] = salaryList
names
# Out:
# 6850.57
# 7691.56
# 5778.45
# 6526.77
# 6910.46
# 6383.46
# 6276.97
# 6069.86
# 6187.87
# 6465.4
# 5868.83
# 6454.58
# 6420.66
# 5862.06
# 5714.79
# 5760.78
# 5000.39
# 5981.03
# 6311.93
# 6398.43
# 6803.64
# 5505.19
# 7037.89
# 6280.84
# 6630.31
# 7104.74
# 6612.28
# 6359.4
# 5194.1
# 6177.33
# 5374.54
# 6472.76
# 5188.95
# 5884.53
# 6634.66
# 5329.52
# 5856.25
# 5852.19
# 6301.76
# 6162.15
# 5061.47
# 5883.98
# 5913.59
# 6112.56
# 4997.72
# 7599.85
# 5806.21
# 5534.34
# 6518.68
# 5967.46
# 6075.78
# 6139.85
# 6342.94
# 7046.36
# 5163.77
# 5576.82
# 6282.09
# 6117.9
# 6060.1
# 6169.41
# 5988.54
# 5193.09
# 6154.53
# 6073.16
# 6962.45
# 6907.18
# 5278.04
# 5456.66
# 5305.04
# 6815.46
# 5229.32
# 6404.23
# 5382.21
# 5328.37
# 6218.74
# 6037.46
# 5958.81
# 5882.48
# 6231.49
# 5964.39
# 6525.99
# 6235.15
# 6701.99
# 6862.59
# 6612.63
# 5819.2
# 6789.75
# 5880.3
# 5912.16
# 5638.11
# 6310.29
# 6097.79
# 7271.29
# 5240.19
# 6579.94
# 6583.76
# 6325.5
# 6453.63
# 6303.03
# 6444.34
# ...

# %%
for i in range(names.shape[0]):
    names.iloc[i]['salary']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-579a01eff03e> in <module>()
# ----> 1 names['salary'] = names['salary'][0]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2329         else:
#    2330             # set column
# -> 2331             self._set_item(key, value)
#    2332
#    2333     def _setitem_slice(self, key, value):
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2395
#    2396         self._ensure_valid_index(value)
# -> 2397         value = self._sanitize_column(key, value)
#    2398         NDFrame._set_item(self, key, value)
#    2399
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    2566
#    2567             # turn me into an ndarray
# ...

# %%
transaction = pd.read_csv('transaction.csv')
transaction
# Out:
#                        time             name gender  age  \
# 0       2017-07-02 22:27:48  Rachel Trujillo   male   36
# 1       2017-06-10 12:37:05  Rachel Trujillo   male   36
# 2       2017-06-07 14:24:02  Rachel Trujillo   male   36
# 3       2017-06-25 15:36:22  Rachel Trujillo   male   36
# 4       2017-06-30 03:34:48  Rachel Trujillo   male   36
